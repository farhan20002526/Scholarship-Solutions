# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_excel("10 universities.xlsx")
df
# Out:
#                                     Universities  ...  CGPA
# 0         University of Arkansas at Little Rock   ...     2
# 1    University of Colorado at Colorado Springs   ...  3.25
# 2                  Western Governors University   ...     2
# 3             University of Louisiana at Monroe   ...   2.5
# 4       The University of Maine at Presque Isle   ...   2.5
# ..                                           ...  ...   ...
# 196                         Wayne State College   ...   2.4
# 197                          Webster University   ...   2.5
# 198                Western Governors University   ...     2
# 199                    Wichita State University   ...   2.5
# 200                 Youngstown State University   ...   2.7
#
# [201 rows x 5 columns]

# %%
df1=df.dropna()

# %%
df1
# Out:
#                                     Universities  ...  CGPA
# 0         University of Arkansas at Little Rock   ...     2
# 1    University of Colorado at Colorado Springs   ...  3.25
# 3             University of Louisiana at Monroe   ...   2.5
# 4       The University of Maine at Presque Isle   ...   2.5
# 5          University of Maryland Eastern Shore   ...   3.5
# ..                                           ...  ...   ...
# 196                         Wayne State College   ...   2.4
# 197                          Webster University   ...   2.5
# 198                Western Governors University   ...     2
# 199                    Wichita State University   ...   2.5
# 200                 Youngstown State University   ...   2.7
#
# [188 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'universities_df' with "Universities" and "CGPA" columns
# Example data
universities = df1["Universities"]
cgpa = df1["CGPA"]

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(universities, cgpa, marker='o', color='blue', alpha=0.7)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel("Universities")
plt.ylabel("CGPA")
plt.title("CGPA vs. Universities")
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3340\1863502337.py in <module>
#       8 # Create a scatter plot
#       9 plt.figure(figsize=(10, 6))
# ---> 10 plt.scatter(universities, cgpa, marker='o', color='blue', alpha=0.7)
#      11 plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
#      12 plt.xlabel("Universities")
#
# D:\Data_Science\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2817         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2818         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2819     __ret = gca().scatter(
#    2820         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2821         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# D:\Data_Science\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\Data_Science\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4449         offsets = np.ma.column_stack([x, y])
#    4450
# -> 4451         collection = mcoll.PathCollection(
#    4452                 (path,), scales,
#    4453                 facecolors=colors,
#
# D:\Data_Science\lib\site-packages\matplotlib\collections.py in __init__(self, paths, sizes, **kwargs)
#    1010         """
#    1011
# -> 1012         super().__init__(**kwargs)
#    1013         self.set_paths(paths)
#    1014         self.set_sizes(sizes)
#
# D:\Data_Science\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     194
#     195         if offsets is not None:
# --> 196             offsets = np.asanyarray(offsets, float)
#     197             # Broadcast (2,) -> (1, 2) but nothing else.
#     198             if offsets.shape == (2,):
#
# ValueError: could not convert string to float: '2.5-3.0'
